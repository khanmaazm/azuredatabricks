# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Below command is to run on the Databricks Filesystem such as ls on the server to see the files
# Normal Text

# %%
# %fs
ls 'dbfs:/FileStore/tables'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/advertising.csv</td><td>advertising.csv</td><td>105363</td></tr><tr><td>dbfs:/FileStore/tables/advertising.json/</td><td>advertising.json/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/advertising1.json/</td><td>advertising1.json/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/advertising2.json/</td><td>advertising2.json/</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/updateadvertising.csv</td><td>updateadvertising.csv</td><td>16725</td></tr></tbody></table></div>

# %%
spark.conf.set("fs.azure.account.key.ailandingareaadls.blob.core.windows.net","OqURIFIIeh5FTGl/X3xKoW4uWhOh8wZrj8q/n1UMtMZsPqfvI9u3Ln6pDkwuGCxVlobjCwZS2xnxREHT8lT/CA==")
thisissparkdfnotpandas = spark.read.csv("wasbs://customer@ailandingareaadls.blob.core.windows.net/advertising.csv", header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(thisissparkdfnotpandas)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DataFrame[Daily Time Spent on Site: string, Age: string, Area Income: string, Daily Internet Usage: string, Ad Topic Line: string, City: string, Male: string, Country: string, Timestamp: string, Clicked on Ad: string]
# </div>

# %%
display(thisissparkdfnotpandas)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spkdfwohdr=spark.read.format("csv").option("header", "true").load("wasbs://customer@ailandingareaadls.blob.core.windows.net/advertising.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
type(spkdfwohdr)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: pyspark.sql.dataframe.DataFrame</div>

# %%
display(spkdfwohdr)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Convert Spark Dataframe to Pandas dataframe
pddf = spkdfwohdr.toPandas()
type(pddf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: pandas.core.frame.DataFrame</div>

# %%
pddf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Daily Time Spent on Site</th>
#       <th>Age</th>
#       <th>Area Income</th>
#       <th>Daily Internet Usage</th>
#       <th>Ad Topic Line</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>Clicked on Ad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.9</td>
#       <td>256.09</td>
#       <td>Cloned 5thgeneration orchestration</td>
#       <td>Wrightburgh</td>
#       <td>0</td>
#       <td>Tunisia</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
# ...

# %%
iamsparkdfcreatedfrompandas = spark.createDataFrame(pddf)
type(iamsparkdfcreatedfrompandas)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: pyspark.sql.dataframe.DataFrame</div>

# %%
#Mount Blob Storage to Databricks cluster
#spark.conf.set("fs.azure.account.key.ailandingareaadls.blob.core.windows.net","OqURIFIIeh5FTGl/X3xKoW4uWhOh8wZrj8q/n1UMtMZsPqfvI9u3Ln6pDkwuGCxVlobjCwZS2xnxREHT8lT/CA==")
#thisissparkdfnotpandas = spark.read.csv("wasbs://customer@ailandingareaadls.blob.core.windows.net/advertising.csv", header=True)


dbutils.fs.mount(source = "wasbs://customer@ailandingareaadls.blob.core.windows.net",
  mount_point = "/mnt/custcontainerailandstg",
  extra_configs = {"fs.azure.account.key.ailandingareaadls.blob.core.windows.net":"OqURIFIIeh5FTGl/X3xKoW4uWhOh8wZrj8q/n1UMtMZsPqfvI9u3Ln6pDkwuGCxVlobjCwZS2xnxREHT8lT/CA=="})

#dbutils.fs.mount(source = "wasbs://udemycntr@udemystorage.blob.core.windows.net",
#  mount_point = "/mnt/afiamountstg",
#  extra_configs = {"fs.azure.account.key.udemystorage.blob.core.windows.net":"4wJU9qssUxbuiCIyPbuDyhYszTN6+QTRU6BLklwlq/QmfM5sQ1e14ruNRLzrvhtB6t107p83LO/Z6aK76/Seow=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %%
import pandas as pd
testdfmntfile = pd.read_csv('/dbfs/mnt/custcontainerailandstg/airbnb/fileupload.csv') #file with columns saluation firstname lastname
testdfmntfile
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>srini</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rock</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>hanuman</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# %fs ls dbfs:/mnt
psadsad = spark.read.csv("/mnt/afiamountstg/udemyfolder/allsuperstore.csv")
#pandasdfmntblobstrg = pd.read_csv("/FileStore/tables/allsuperstore.csv")
#pandasdfmntblobstrg = pd.read_csv("/mnt/afiamountstg/udemyfolder/allsuperstore.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
type(iamsparkdfcreatedfrompandas["Age"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
def get_full_name (salutation,first_name,last_name):
  print(salutation, first_name, last_name)
  salutation = salutation.upper()
  first_name = first_name.capitalize()
  last_name = last_name.capitalize()
  print('Update', salutation, first_name, last_name)
  return (salutation+' '+ first_name +' ' + last_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
testdfmntfile[['salutation','firstname','lastname']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">KeyError</span>                                  Traceback (most recent call last)
# ...

# %%
testdfmntfile['upperofname'] = testdfmntfile['name'].apply(lambda x: x.upper())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df['col_3'] = df.apply(lambda x: get_sublist(x.col_1, x.col_2), axis=1)
testdfmntfile['propername'] = testdfmntfile.apply(lambda x: get_full_name(x.salutation,x.firstname,x.lastname), axis = 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# ...

# %%
testdfmntfile
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>upperofname</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>srini</td>
#       <td>SRINI</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rock</td>
#       <td>ROCK</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>hanuman</td>
#       <td>HANUMAN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
testdfmntfile['salutation'] = ['mr.','Mr.','mR.']
testdfmntfile['firstname'] = testdfmntfile['name']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
get_full_name('mr.','Dwayne', 'Johnson')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mr. Dwayne Johnson
# Update MR. Dwayne Johnson
# Out[10]: &#39;MR. Dwayne Johnson&#39;</div>

# %%
get_full_name = lambda salutation, first_name, last_name: (salutation.upper() +' '+ first_name.capitalize() +' ' + last_name.capitalize())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
get_full_name('mr.','dwayne', 'JohNson')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: &#39;MR. Dwayne Johnson&#39;</div>

# %%
get_full_name('Ms.','Letty', 'Ortiz')

# %%
combined_length("hello","there")
