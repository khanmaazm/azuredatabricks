# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
advertisingdf.head #.tail
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
advertisingdf = pd.read_csv("/dbfs/FileStore/tables/advertising.csv", header='infer')
type(advertisingdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">FileNotFoundError</span>                         Traceback (most recent call last)
# ...

# %%
advertisingdf.head() #.tail
print(advertisingdf.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Index([&#39;Daily Time Spent on Site&#39;, &#39;Age&#39;, &#39;Area Income&#39;,
#        &#39;Daily Internet Usage&#39;, &#39;Ad Topic Line&#39;, &#39;City&#39;, &#39;Male&#39;, &#39;Country&#39;,
#        &#39;Timestamp&#39;, &#39;Clicked on Ad&#39;],
#       dtype=&#39;object&#39;)
# </div>

# %%
advertisingdf.columns = ['DailyTimeSpentonSite', 'Age', 'AreaIncome', 'DailyInternetUsage', 'AdTopicLine', 'City', 'Male', 'Country','Timestamp', 'ClickedonAd']
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>Cloned 5thgeneration orchestration</td>
#       <td>Wrightburgh</td>
#       <td>0</td>
#       <td>Tunisia</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
#     </tr>
# ...

# %%
advertisingdf.sort_values(by=['ClickedonAd'],ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>500</th>
#       <td>51.56</td>
#       <td>46</td>
#       <td>63102.19</td>
#       <td>124.85</td>
#       <td>Business-focused client-driven forecast</td>
#       <td>Helenborough</td>
#       <td>0</td>
#       <td>Australia</td>
#       <td>07/01/2016 13:58</td>
#       <td>1</td>
# ...

# %%
advertisingdf['ClickedonAd'].value_counts()
#Python List
#Numpy  Array (ndarray)
#Pandas Dataframe/Series - if it is a single dimension. Dataframe is multiple series. Internally Pandas is using numpy arrays as Series
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 1    500
# 0    500
# Name: ClickedonAd, dtype: int64</div>

# %%
x = advertisingdf['Age'].value_counts()
print(type(x))
x.head()
x.shape #single dimension '43'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.series.Series&#39;&gt;
# Out[8]: (43,)</div>

# %%
advertisingdf[(advertisingdf['ClickedonAd'] == 1)].head()
#equivalent to query "select * from advertisingdf where ClickedonAd = 1 and rownum <= 5"
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>66.00</td>
#       <td>48</td>
#       <td>24593.33</td>
#       <td>131.76</td>
#       <td>Reactive local challenge</td>
#       <td>Port Jefferybury</td>
#       <td>1</td>
#       <td>Australia</td>
#       <td>07/03/2016 01:40</td>
#       <td>1</td>
#     </tr>
# ...

# %%
advertisingdf[(advertisingdf['ClickedonAd'] == 1) & (advertisingdf['Country'] == 'Australia')].head()
#SQL equivalent is select * from advertisingdf where ClickedonAd = 1 AND Country = 'Australia' and ROWNUM <= 5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>66.00</td>
#       <td>48</td>
#       <td>24593.33</td>
#       <td>131.76</td>
#       <td>Reactive local challenge</td>
#       <td>Port Jefferybury</td>
#       <td>1</td>
#       <td>Australia</td>
#       <td>07/03/2016 01:40</td>
#       <td>1</td>
#     </tr>
# ...

# %%
advertisingdf[(advertisingdf.ClickedonAd == 1) & (advertisingdf.Country == 'Australia')].head()
#advertisingdf['Age'] #selecting a column
#advertising. #calling a function
type(advertisingdf['Age'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: pandas.core.series.Series</div>

# %%
advertisingdf[(advertisingdf['ClickedonAd'].isna() == False)].head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>Cloned 5thgeneration orchestration</td>
#       <td>Wrightburgh</td>
#       <td>0</td>
#       <td>Tunisia</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
#     </tr>
# ...

# %%
sns.pairplot(data=advertisingdf)

# %%
z = advertisingdf.drop('City', axis = 1)
z.head()
z = advertisingdf.drop(['City','AdTopicLine','Country'], axis = 1)
z.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>0</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
# ...

# %%
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>AdTopicLine</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>Cloned 5thgeneration orchestration</td>
#       <td>Wrightburgh</td>
#       <td>0</td>
#       <td>Tunisia</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
#     </tr>
# ...

# %%
advertisingdf.drop(['City','AdTopicLine','Country'], axis = 1,inplace= True) #axis = 1 means columns and inplace = True means drop in source dataframe
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>0</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
# ...

# %%
advertisingdf.drop([0, 3, 4, 98, 125, 7, 900], axis = 0,inplace= True) #axis = 0 means rows
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>69.47</td>
#       <td>26</td>
#       <td>59785.94</td>
#       <td>236.50</td>
#       <td>0</td>
#       <td>13/03/2016 20:35</td>
# ...

# %%
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create Dataframe from multiple Series
clickedonadseries = advertisingdf['ClickedonAd']
ageseries = advertisingdf['Age']
randomnos1000 = np.random.randint(1, 10000, 993)
print(randomnos1000.shape)
print(type(clickedonadseries))
print(type(ageseries))
print(type(randomnos1000))
randomnos1000series = pd.Series(randomnos1000)
print(type(randomnos1000series))
print(randomnos1000series.shape)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(993,)
# &lt;class &#39;pandas.core.series.Series&#39;&gt;
# &lt;class &#39;pandas.core.series.Series&#39;&gt;
# &lt;class &#39;numpy.ndarray&#39;&gt;
# &lt;class &#39;pandas.core.series.Series&#39;&gt;
# (993,)
# </div>

# %%
dataframefromseries = pd.DataFrame([clickedonadseries, ageseries, randomnos1000]).T
dataframefromseries.columns = ['Clicked','AgeofProspect','Randomint']

dataframefromseries.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Clicked</th>
#       <th>AgeofProspect</th>
#       <th>Randomint</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>31.0</td>
#       <td>6196.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>26.0</td>
#       <td>8383.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.0</td>
#       <td>23.0</td>
#       <td>5395.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.0</td>
#       <td>33.0</td>
#       <td>2403.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.0</td>
#       <td>30.0</td>
# ...

# %%
dataframefromseries = pd.DataFrame()
clickedonadseries = dataframefromseries['Clicked'] 
ageseries = dataframefromseries['AgeofProspect']
randomnos1000 = dataframefromseries['Randomint']
dataframefromseries['AgeofProspect'] = dataframefromseries['AnotherAge'] #it can also be totally from a different dataframe
xvar = 'Didheclickcolumn'
colname = 'Clicked'
dataframefromseries[xvar] = dataframefromseries[colname]
dataframefromseries.head()

# %%
dataframefromseries = pd.DataFrame()
dataframefromseries['Clicked'] = clickedonadseries
dataframefromseries['AgeofProspect'] = ageseries
dataframefromseries['Randomint'] = randomnos1000 
dataframefromseries['AnotherAge'] = dataframefromseries['AgeofProspect']
dataframefromseries.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Clicked</th>
#       <th>AgeofProspect</th>
#       <th>Randomint</th>
#       <th>AnotherAge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>31</td>
#       <td>3604</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>26</td>
#       <td>6196</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0</td>
#       <td>23</td>
#       <td>8383</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0</td>
#       <td>33</td>
#       <td>8948</td>
#       <td>33</td>
# ...

# %%
dataframefromseries.to_csv('/dbfs/FileStore/tables/updateadvertising.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataframefromseries.index
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[90]: RangeIndex(start=0, stop=993, step=1)</div>

# %%
dataframefromseries.reset_index(inplace=True, drop=True)#drop = True will not create index column
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataframefromseries.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Clicked</th>
#       <th>AgeofProspect</th>
#       <th>Randomint</th>
#       <th>AnotherAge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>31</td>
#       <td>3604</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>26</td>
#       <td>6196</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>23</td>
#       <td>8383</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>33</td>
#       <td>8948</td>
#       <td>33</td>
# ...

# %%
advertisingdf.index
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: RangeIndex(start=0, stop=993, step=1)</div>

# %%
indexofdf = dataframefromseries.index
type(indexofdf)
print(indexofdf)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">RangeIndex(start=0, stop=993, step=1)
# </div>

# %%
advertisingdf.set_index(keys=indexofdf, inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69.47</td>
#       <td>26</td>
#       <td>59785.94</td>
#       <td>236.50</td>
#       <td>0</td>
#       <td>13/03/2016 20:35</td>
# ...

# %%
print(dataframefromseries['AgeofProspect'].count())
print(dataframefromseries['AgeofProspect'].nunique())
print(dataframefromseries['AgeofProspect'].unique())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">993
# 43
# [31 26 23 33 30 20 49 37 48 24 41 36 40 35 52 28 34 22 57 53 39 46 29 32
#  25 43 45 50 47 27 42 38 54 21 60 55 44 58 56 51 19 59 61]
# </div>

# %%
print(dataframefromseries.max())
print(type(dataframefromseries.max()))
print(pd.DataFrame(dataframefromseries.max()).index)
print(pd.DataFrame(dataframefromseries.max()).values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Clicked             1
# AgeofProspect      61
# Randomint        9999
# AnotherAge         61
# dtype: int64
# &lt;class &#39;pandas.core.series.Series&#39;&gt;
# Index([&#39;Clicked&#39;, &#39;AgeofProspect&#39;, &#39;Randomint&#39;, &#39;AnotherAge&#39;], dtype=&#39;object&#39;)
# [[   1]
#  [  61]
#  [9999]
#  [  61]]
# </div>

# %%
advertisingdf.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>993.000000</td>
#       <td>993.000000</td>
#       <td>993.000000</td>
#       <td>993.000000</td>
#       <td>993.000000</td>
#       <td>993.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>65.011853</td>
#       <td>35.985901</td>
#       <td>55006.871339</td>
#       <td>179.888812</td>
#       <td>0.482377</td>
#       <td>0.500504</td>
# ...

# %%
advertisingdf.describe().transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>DailyTimeSpentonSite</th>
#       <td>993.0</td>
#       <td>65.011853</td>
#       <td>15.865350</td>
#       <td>32.60</td>
#       <td>51.38</td>
#       <td>68.18</td>
#       <td>78.57</td>
#       <td>91.43</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>993.0</td>
#       <td>35.985901</td>
#       <td>8.785286</td>
#       <td>19.00</td>
#       <td>29.00</td>
# ...

# %%
advertisingdf.describe().transpose()['std'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: 8.785286        1
# 43.816336       1
# 0.499941        1
# 13409.277406    1
# 0.500252        1
# 15.865350       1
# Name: std, dtype: int64</div>

# %%
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>69.47</td>
#       <td>26</td>
#       <td>59785.94</td>
#       <td>236.50</td>
#       <td>0</td>
#       <td>13/03/2016 20:35</td>
# ...

# %%
pd.pivot_table(advertisingdf,values=['Age','DailyTimeSpentonSite'],columns=['ClickedonAd'], aggfunc=np.mean, index=['Male']).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Male</th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ClickedonAd</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">Age</th>
#       <th>0</th>
#       <td>31.983806</td>
#       <td>31.373494</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40.011236</td>
#       <td>40.604348</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">DailyTimeSpentonSite</th>
#       <th>0</th>
#       <td>77.057247</td>
#       <td>76.719398</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...

# %%
pd.pivot_table(advertisingdf,values=['Age','DailyTimeSpentonSite','Male'],columns=['ClickedonAd'], aggfunc=np.mean).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Male</th>
#     </tr>
#     <tr>
#       <th>ClickedonAd</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.677419</td>
#       <td>76.887641</td>
#       <td>0.502016</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40.285714</td>
#       <td>53.159960</td>
#       <td>0.462777</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
advertisingdf.reset_index(inplace=True)
dataframefromseries.reset_index(inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# ...

# %%
advertisingdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_0</th>
#       <th>index</th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
#       <td>04/04/2016 01:39</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>69.47</td>
# ...

# %%
dataframefromseries.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Clicked</th>
#       <th>AgeofProspect</th>
#       <th>Randomint</th>
#       <th>AnotherAge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>31</td>
#       <td>3604</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>26</td>
#       <td>6196</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>0</td>
#       <td>23</td>
#       <td>8383</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
#join is exactly like SQL joins
newdf = advertisingdf.join(dataframefromseries, on=['index'], how = 'inner', lsuffix = 'adv')
newdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_0</th>
#       <th>indexadv</th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>Male</th>
#       <th>Timestamp</th>
#       <th>ClickedonAd</th>
#       <th>index</th>
#       <th>Clicked</th>
#       <th>AgeofProspect</th>
#       <th>Randomint</th>
#       <th>AnotherAge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>80.23</td>
#       <td>31</td>
#       <td>68441.85</td>
#       <td>193.77</td>
#       <td>1</td>
# ...

# %%
#If rowwise concatenate is done it is like UNION in SQL
pd.concat(objs = [advertisingdf, dataframefromseries, newdf], axis = 0).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#       <th>AgeofProspect</th>
#       <th>AnotherAge</th>
#       <th>AreaIncome</th>
#       <th>Clicked</th>
#       <th>ClickedonAd</th>
#       <th>DailyInternetUsage</th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Male</th>
#       <th>Randomint</th>
#       <th>Timestamp</th>
#       <th>index</th>
#       <th>indexadv</th>
#       <th>level_0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>68441.85</td>
#       <td>NaN</td>
#       <td>0.0</td>
#       <td>193.77</td>
#       <td>80.23</td>
# ...

# %%
#EQUIVALENT SQL IS select male, sum(level_0), sum(index), sum(DailyTimeSpentonSite), sum(Age), sum(AreaIncome), sum(DailyInternetUsage), sum(ClikedonAd)
#from advertisingdf group by male 
advertisingdf.groupby('Male').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>level_0</th>
#       <th>index</th>
#       <th>DailyTimeSpentonSite</th>
#       <th>Age</th>
#       <th>AreaIncome</th>
#       <th>DailyInternetUsage</th>
#       <th>ClickedonAd</th>
#     </tr>
#     <tr>
#       <th>Male</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>478.714008</td>
#       <td>478.714008</td>
#       <td>65.334358</td>
#       <td>36.153696</td>
#       <td>54936.505973</td>
#       <td>178.624591</td>
#       <td>0.519455</td>
# ...

# %%
print(advertisingdf[(advertisingdf['Ad Topic Line'].isnull() == True)])

print(advertisingdf.isnull())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Empty DataFrame
# Columns: [Daily Time Spent on Site, Age, Area Income, Daily Internet Usage, Ad Topic Line, City, Male, Country, Timestamp, Clicked on Ad]
# Index: []
#      Daily Time Spent on Site    Age  ...  Timestamp  Clicked on Ad
# 0                       False  False  ...      False          False
# 1                       False  False  ...      False          False
# 2                       False  False  ...      False          False
# 3                       False  False  ...      False          False
# 4                       False  False  ...      False          False
# ...

# %%
advertisingdf.dropna()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Daily Time Spent on Site</th>
#       <th>Age</th>
#       <th>Area Income</th>
#       <th>Daily Internet Usage</th>
#       <th>Ad Topic Line</th>
#       <th>City</th>
#       <th>Male</th>
#       <th>Country</th>
#       <th>Timestamp</th>
#       <th>Clicked on Ad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>68.95</td>
#       <td>35</td>
#       <td>61833.90</td>
#       <td>256.09</td>
#       <td>Cloned 5thgeneration orchestration</td>
#       <td>Wrightburgh</td>
#       <td>0</td>
#       <td>Tunisia</td>
#       <td>27/03/2016 00:53</td>
#       <td>0</td>
# ...

# %%
df1 = pd.DataFrame({'numbers': [1, 2, 3], 'colors': ['red', 'white', 'blue']})
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2 = pd.DataFrame({
                    'numbers': [1, 2, 3,4],
                    'colors': ['red', 'white', 'blue','green']
                    })
print(type(df2))
print(df2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
#    numbers colors
# 0        1    red
# 1        2  white
# 2        3   blue
# 3        4  green
# </div>

# %%
pd.concat([df1,df2],axis=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
pd.concat([df1,df2],axis=1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors</th>
#       <th>numbers</th>
#       <th>colors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>red</td>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#       <td>white</td>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.0</td>
#       <td>blue</td>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4</td>
#       <td>green</td>
# ...

# %%
mouti = pd.merge(df1,df2, on='numbers', how='inner')
mouti
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors_x</th>
#       <th>colors_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#       <td>blue</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
mouto = pd.merge(df1,df2, on='numbers', how='outer')
mouto
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors_x</th>
#       <th>colors_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>NaN</td>
#       <td>green</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
moutl = pd.merge(df1,df2, on='numbers', how='left')
moutl
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors_x</th>
#       <th>colors_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#       <td>blue</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
moutr = pd.merge(df1,df2, on='numbers', how='right')
moutr
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors_x</th>
#       <th>colors_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>NaN</td>
#       <td>green</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
moutj = pd.merge(df1,df2, on=['numbers','colors'], how='right')
moutj
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>green</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df11 = df1.copy(deep=True)
df11
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>numbers</th>
#       <th>colors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>red</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>white</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>blue</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df11.reset_index(inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(df11)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">   numbers colors
# 0        1    red
# 1        2  white
# 2        3   blue
# </div>
